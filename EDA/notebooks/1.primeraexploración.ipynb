# %% [markdown]
# # Brecha salarial entre hombres y mujeres

# %% [markdown]
# ![](https://cdn.prod.website-files.com/5f4f67c5950db17954dd4f52/6422fc2899987b74dc89c4b6_diferencias%20salariales.webp)

# %% [markdown]
# ### Definición del problema

# %% [markdown]
# La brecha de ingresos entre hombres y mujeres es un problema que afecta a las mujeres de todos los países. En  la actualidad hay un debate sobre si la brecha de género es algo del pasado o sigue ocurriendo en la actualidad. Por lo que en el siguiente EDA tiene como finalidad mostrar la situación en la ultima decada y en que sectores laborales hay más diferencias.

# %% [markdown]
# ### Sobre el conjunto de datos

# %% [markdown]
# Este dataSet contiene el salario promedio por hora en los empleados, por sexo, edad y ocupación, mediante el Indicador 8.5.1 (Ingresos promedio por hora de los empleados, por sexo, edad, ocupación). Los datos han sido recogidos en ILOSTAT (International Labour Organization),un portal estadistico que recoge los datos sociolaborales.

# %% [markdown]
# ### Preguntas clave

# %% [markdown]
# 1. ¿Existe diferencia en ingresos entre hombres y mujeres?
#
# 2. ¿Hay alguna profesion en la que las mujeres ganen mas que los hombres?
#
# 3. ¿Cuál es el sector laboral en el que la brecha de ingresos es mayor?
#
# 4. ¿Cuál es el país con las mayores diferencias salariales?
#
# 5. ¿ Hay algún patrón en países respecto a la brecha salarial?
#
# 6. ¿ Ha evolucionado en los ultimos años la brecha salarial?

# %% [markdown]
# ### Librerías

# %%
#Tratamiento de los datos
import numpy as np
import pandas as pd
#Visualización
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import scipy.stats as stats
#Estadisticas
from scipy.stats import f_oneway,pearsonr, ttest_ind, ttest_rel, shapiro, levene, mannwhitneyu, kruskal, chi2_contingency
import warnings
warnings.filterwarnings('ignore')
import sys
import os

# %% [markdown]
# ### Carga de datos

# %%
df=pd.read_csv('/Users/isaromobru/Desktop/EDA/data/raw/SDG_0851_SEX_OCU_NB_A-filtered-2024-12-17.csv')

# %% [markdown]
# # 1. Primera Observación

# %% [markdown]
# ### Estructura del Dataframe en bruto

# %%
pd.set_option('display.max_colwidth',None)
df.copy()
df
# Out:
#      ref_area.label  \
# 0           Albania
# 1           Albania
# 2           Albania
# 3           Albania
# 4           Albania
# ...             ...
# 7741        Ukraine
# 7742        Ukraine
# 7743        Ukraine
# 7744        Ukraine
# 7745        Ukraine
#
#                                                                             source.label  \
# 0                                                      ES - Structure of Earnings Survey
# 1                                                      ES - Structure of Earnings Survey
# 2                                                      ES - Structure of Earnings Survey
# 3                                                      ES - Structure of Earnings Survey
# 4                                                      ES - Structure of Earnings Survey
# ...                                                                                  ...
# 7741  ES - Survey on wages of employees by gender, age, education and Occupational group
# 7742  ES - Survey on wages of employees by gender, age, education and Occupational group
# 7743  ES - Survey on wages of employees by gender, age, education and Occupational group
# 7744  ES - Survey on wages of employees by gender, age, education and Occupational group
# 7745  ES - Survey on wages of employees by gender, age, education and Occupational group
#
#                                                                          indicator.label  \
# 0     SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 1     SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 2     SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 3     SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 4     SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# ...                                                                                  ...
# 7741  SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 7742  SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 7743  SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 7744  SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 7745  SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
#
#         sex.label  \
# 0      Sex: Total
# 1      Sex: Total
# 2      Sex: Total
# 3      Sex: Total
# 4       Sex: Male
# ...           ...
# 7741  Sex: Female
# 7742  Sex: Female
# 7743  Sex: Female
# 7744  Sex: Female
# 7745  Sex: Female
#
#                                                                    classif1.label  \
# 0                                                 Occupation (Skill level): Total
# 1                           Occupation (Skill level): Skill levels 3 and 4 ~ high
# 2                                Occupation (Skill level): Skill level 2 ~ medium
# 3                                   Occupation (Skill level): Skill level 1 ~ low
# 4                                                 Occupation (Skill level): Total
# ...                                                                           ...
# 7741                           Occupation (ISCO-08): 5. Service and sales workers
# 7742  Occupation (ISCO-08): 6. Skilled agricultural, forestry and fishery workers
# 7743                    Occupation (ISCO-08): 7. Craft and related trades workers
# 7744         Occupation (ISCO-08): 8. Plant and machine operators, and assemblers
# 7745                              Occupation (ISCO-08): 9. Elementary occupations
#
#       time  obs_value obs_status.label  note_classif.label  \
# 0     2018     293.00              NaN                 NaN
# 1     2018    1315.00              NaN                 NaN
# 2     2018    1109.00              NaN                 NaN
# 3     2018     189.00              NaN                 NaN
# 4     2018     303.00              NaN                 NaN
# ...    ...        ...              ...                 ...
# 7741  2016      16.90              NaN                 NaN
# 7742  2016      21.91              NaN                 NaN
# 7743  2016      24.95              NaN                 NaN
# 7744  2016      25.40              NaN                 NaN
# 7745  2016      16.32              NaN                 NaN
#
#                                                                                                                             note_indicator.label  \
# 0                                                                                                                      Currency: ALB - Lek (ALL)
# 1                                                                                                                      Currency: ALB - Lek (ALL)
# 2                                                                                                                      Currency: ALB - Lek (ALL)
# 3                                                                                                                      Currency: ALB - Lek (ALL)
# 4                                                                                                                      Currency: ALB - Lek (ALL)
# ...                                                                                                                                          ...
# 7741  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: UKR - Hryvnia (UAH)
# 7742  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: UKR - Hryvnia (UAH)
# 7743  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: UKR - Hryvnia (UAH)
# 7744  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: UKR - Hryvnia (UAH)
# 7745  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: UKR - Hryvnia (UAH)
#
#                                                                                                                                                                                                                                                                        note_source.label
# 0     Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
# 1     Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
# 2     Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
# 3     Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
# 4     Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
# ...                                                                                                                                                                                                                                                                                  ...
# 7741                                                                                                                                                                                                                         Geographical coverage: Total national, excluding some areas
# 7742                                                                                                                                                                                                                         Geographical coverage: Total national, excluding some areas
# 7743                                                                                                                                                                                                                         Geographical coverage: Total national, excluding some areas
# 7744                                                                                                                                                                                                                         Geographical coverage: Total national, excluding some areas
# 7745                                                                                                                                                                                                                         Geographical coverage: Total national, excluding some areas
#
# [7746 rows x 11 columns]

# %% [markdown]
# 1. Estructura del registro

# %%
df.shape
# Out:
# (7746, 11)

# %% [markdown]
# 2. Número de Columnas

# %%
df.columns
# Out:
# Index(['ref_area.label', 'source.label', 'indicator.label', 'sex.label',
#        'classif1.label', 'time', 'obs_value', 'obs_status.label',
#        'note_classif.label', 'note_indicator.label', 'note_source.label'],
#       dtype='object')

# %% [markdown]
# 3. Espacio e información general

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7746 entries, 0 to 7745
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ref_area.label        7746 non-null   object
#  1   source.label          7746 non-null   object
#  2   indicator.label       7746 non-null   object
#  3   sex.label             7746 non-null   object
#  4   classif1.label        7746 non-null   object
#  5   time                  7746 non-null   int64
#  6   obs_value             7690 non-null   float64
#  7   obs_status.label      319 non-null    object
#  8   note_classif.label    0 non-null      float64
#  9   note_indicator.label  7746 non-null   object
#  10  note_source.label     7746 non-null   object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 665.8+ KB

# %% [markdown]
# 4. Vista general de Dataframe

# %%
df.head()
# Out:
#   ref_area.label                       source.label  \
# 0        Albania  ES - Structure of Earnings Survey
# 1        Albania  ES - Structure of Earnings Survey
# 2        Albania  ES - Structure of Earnings Survey
# 3        Albania  ES - Structure of Earnings Survey
# 4        Albania  ES - Structure of Earnings Survey
#
#                                                                       indicator.label  \
# 0  SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 1  SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 2  SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 3  SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 4  SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
#
#     sex.label                                         classif1.label  time  \
# 0  Sex: Total                        Occupation (Skill level): Total  2018
# 1  Sex: Total  Occupation (Skill level): Skill levels 3 and 4 ~ high  2018
# 2  Sex: Total       Occupation (Skill level): Skill level 2 ~ medium  2018
# 3  Sex: Total          Occupation (Skill level): Skill level 1 ~ low  2018
# 4   Sex: Male                        Occupation (Skill level): Total  2018
#
#    obs_value obs_status.label  note_classif.label       note_indicator.label  \
# 0      293.0              NaN                 NaN  Currency: ALB - Lek (ALL)
# 1     1315.0              NaN                 NaN  Currency: ALB - Lek (ALL)
# 2     1109.0              NaN                 NaN  Currency: ALB - Lek (ALL)
# 3      189.0              NaN                 NaN  Currency: ALB - Lek (ALL)
# 4      303.0              NaN                 NaN  Currency: ALB - Lek (ALL)
#
#                                                                                                                                                                                                                                                                     note_source.label
# 0  Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
# 1  Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
# 2  Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
# 3  Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
# 4  Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees

# %%
df.dtypes
# Out:
# ref_area.label           object
# source.label             object
# indicator.label          object
# sex.label                object
# classif1.label           object
# time                      int64
# obs_value               float64
# obs_status.label         object
# note_classif.label      float64
# note_indicator.label     object
# note_source.label        object
# dtype: object

# %%
df.tail()
# Out:
#      ref_area.label  \
# 7741        Ukraine
# 7742        Ukraine
# 7743        Ukraine
# 7744        Ukraine
# 7745        Ukraine
#
#                                                                             source.label  \
# 7741  ES - Survey on wages of employees by gender, age, education and Occupational group
# 7742  ES - Survey on wages of employees by gender, age, education and Occupational group
# 7743  ES - Survey on wages of employees by gender, age, education and Occupational group
# 7744  ES - Survey on wages of employees by gender, age, education and Occupational group
# 7745  ES - Survey on wages of employees by gender, age, education and Occupational group
#
#                                                                          indicator.label  \
# 7741  SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 7742  SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 7743  SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 7744  SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 7745  SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
#
#         sex.label  \
# 7741  Sex: Female
# 7742  Sex: Female
# 7743  Sex: Female
# 7744  Sex: Female
# 7745  Sex: Female
#
#                                                                    classif1.label  \
# 7741                           Occupation (ISCO-08): 5. Service and sales workers
# 7742  Occupation (ISCO-08): 6. Skilled agricultural, forestry and fishery workers
# 7743                    Occupation (ISCO-08): 7. Craft and related trades workers
# 7744         Occupation (ISCO-08): 8. Plant and machine operators, and assemblers
# 7745                              Occupation (ISCO-08): 9. Elementary occupations
#
#       time  obs_value obs_status.label  note_classif.label  \
# 7741  2016      16.90              NaN                 NaN
# 7742  2016      21.91              NaN                 NaN
# 7743  2016      24.95              NaN                 NaN
# 7744  2016      25.40              NaN                 NaN
# 7745  2016      16.32              NaN                 NaN
#
#                                                                                                                             note_indicator.label  \
# 7741  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: UKR - Hryvnia (UAH)
# 7742  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: UKR - Hryvnia (UAH)
# 7743  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: UKR - Hryvnia (UAH)
# 7744  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: UKR - Hryvnia (UAH)
# 7745  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: UKR - Hryvnia (UAH)
#
#                                                 note_source.label
# 7741  Geographical coverage: Total national, excluding some areas
# 7742  Geographical coverage: Total national, excluding some areas
# 7743  Geographical coverage: Total national, excluding some areas
# 7744  Geographical coverage: Total national, excluding some areas
# 7745  Geographical coverage: Total national, excluding some areas

# %%
df.isnull().sum()
# Out:
# ref_area.label             0
# source.label               0
# indicator.label            0
# sex.label                  0
# classif1.label             0
# time                       0
# obs_value                 56
# obs_status.label        7427
# note_classif.label      7746
# note_indicator.label       0
# note_source.label          0
# dtype: int64

# %% [markdown]
# Se puede observar que hay 56 valores perdidos en 'obs_value' y las columnas 'obs_status.label', 'note_classif.label', se encuentran practicamente vacías.

# %% [markdown]
# ## 2. Tipos de datos de datos

# %% [markdown]
# |Nombre Variable	|Tipo Propuesto	|Descripción|	tipo Actual|	Missing|
# |---|---|---|---|---|
# |ref_area.label  | categorica|País|	object|0
# |source.label |Categorica |tipo de encuesta|object|0
# |indicator.label |Categorica |Indicador SDG relacionado con ingresos medios por hora.|object|0
# |sex.label |Categorica|Género y total|object|0
# |classif1.label | Categorica |clasificación ocupación  según niveles de habilidad.|object|0
# |time  | datatime| año de referencia de los datos.| int|0
# |obs_value  | float|salario promedio por hora|float|56
# |obs_status.label  |--|---|object|7427|
# |note_indicator.label |--|---|float| 7746|
# |note_source.label |str|Información adicional sobre la fuente (período de referencia, actividad, etc.)|object|0|

# %% [markdown]
# ### Cardinalidad

# %%
cardinalidades = df.nunique()
cardinalidades_porcentaje = (df.nunique() / len(df)) * 100
# Clasificar usando map y lambda
categorias = cardinalidades.map(lambda x: 'Baja' if x < 10 else ('Media' if x <= 50 else 'Alta'))
cardinalidad=pd.DataFrame({'card_abs':cardinalidades,'card_relat(%)':cardinalidades_porcentaje,'Tipo':categorias})
cardinalidad
# Out:
#                       card_abs  card_relat(%)   Tipo
# ref_area.label              39       0.503486  Media
# source.label                14       0.180738  Media
# indicator.label              1       0.012910   Baja
# sex.label                    3       0.038730   Baja
# classif1.label              28       0.361477  Media
# time                        11       0.142009  Media
# obs_value                 3741      48.295895   Alta
# obs_status.label             2       0.025820   Baja
# note_classif.label           0       0.000000   Baja
# note_indicator.label        52       0.671314   Alta
# note_source.label           22       0.284018  Media

# %% [markdown]
# 1. Columnas con alta cardinalidad:
# - obs_value: Debería ser numérica (datos observados).
# - note_indicator.label y ref_area.label: Son variables categóricas útiles para agrupar o segmentar datos.
# 2. Columnas con baja cardinalidad:
# - sex.label, obs_status.label, source.label: Representan categorías claras. Pueden ser convertidas a tipo categórico para optimizar espacio.
# 3. Columnas redundantes o vacías:
# - note_classif.label no tiene datos y puede eliminarse.
# - indicator.label tiene solo un valor único, por lo que no aporta variabilidad.

# %% [markdown]
# ### Tipos de datos apropiados para cada variable

# %% [markdown]
# Observando hay que cambiar el tipo de datos para poder manejarlos y como cambio adicional cambiar el nombre de variables para que sea más fácil identidicarla

# %%
# Convertir los object en categoricas 
text_columns = ['ref_area.label', 'source.label', 'indicator.label', 'sex.label', 'classif1.label', 
                'obs_status.label', 'note_indicator.label', 'note_source.label']

for col in text_columns:
    df[col] = df[col].astype('category')

# %% [markdown]
# ### variable time

# %%
df.dtypes
# Out:
# ref_area.label          category
# source.label            category
# indicator.label         category
# sex.label               category
# classif1.label          category
# time                       int64
# obs_value                float64
# obs_status.label        category
# note_classif.label       float64
# note_indicator.label    category
# note_source.label       category
# dtype: object

# %%
df['time']=pd.to_datetime(df['time'],format='%Y').dt.year

# %%
df['time'].sort_values(ascending=False)
# Out:
# 844     2023
# 5264    2023
# 854     2023
# 855     2023
# 840     2023
#         ...
# 720     2013
# 721     2013
# 722     2013
# 723     2013
# 724     2013
# Name: time, Length: 7746, dtype: int32

# %% [markdown]
# ### consistencia en el naming

# %% [markdown]
# Cambio de nombre de las variables para que sea mas intuitiva en Castellano y snake_case

# %%
df.rename(columns={
    'ref_area.label': 'País',
    'time': 'año',
    'sex.label': 'sexo',
    'obs_value': 'prom_ganancias',
    'classif1.label': 'nivel_laboral',
    'note_indicator.label':'moneda'
   
    
}, inplace=True)
df
# Out:
#          País  \
# 0     Albania
# 1     Albania
# 2     Albania
# 3     Albania
# 4     Albania
# ...       ...
# 7741  Ukraine
# 7742  Ukraine
# 7743  Ukraine
# 7744  Ukraine
# 7745  Ukraine
#
#                                                                             source.label  \
# 0                                                      ES - Structure of Earnings Survey
# 1                                                      ES - Structure of Earnings Survey
# 2                                                      ES - Structure of Earnings Survey
# 3                                                      ES - Structure of Earnings Survey
# 4                                                      ES - Structure of Earnings Survey
# ...                                                                                  ...
# 7741  ES - Survey on wages of employees by gender, age, education and Occupational group
# 7742  ES - Survey on wages of employees by gender, age, education and Occupational group
# 7743  ES - Survey on wages of employees by gender, age, education and Occupational group
# 7744  ES - Survey on wages of employees by gender, age, education and Occupational group
# 7745  ES - Survey on wages of employees by gender, age, education and Occupational group
#
#                                                                          indicator.label  \
# 0     SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 1     SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 2     SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 3     SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 4     SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# ...                                                                                  ...
# 7741  SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 7742  SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 7743  SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 7744  SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 7745  SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
#
#              sexo  \
# 0      Sex: Total
# 1      Sex: Total
# 2      Sex: Total
# 3      Sex: Total
# 4       Sex: Male
# ...           ...
# 7741  Sex: Female
# 7742  Sex: Female
# 7743  Sex: Female
# 7744  Sex: Female
# 7745  Sex: Female
#
#                                                                     nivel_laboral  \
# 0                                                 Occupation (Skill level): Total
# 1                           Occupation (Skill level): Skill levels 3 and 4 ~ high
# 2                                Occupation (Skill level): Skill level 2 ~ medium
# 3                                   Occupation (Skill level): Skill level 1 ~ low
# 4                                                 Occupation (Skill level): Total
# ...                                                                           ...
# 7741                           Occupation (ISCO-08): 5. Service and sales workers
# 7742  Occupation (ISCO-08): 6. Skilled agricultural, forestry and fishery workers
# 7743                    Occupation (ISCO-08): 7. Craft and related trades workers
# 7744         Occupation (ISCO-08): 8. Plant and machine operators, and assemblers
# 7745                              Occupation (ISCO-08): 9. Elementary occupations
#
#        año  prom_ganancias obs_status.label  note_classif.label  \
# 0     2018          293.00              NaN                 NaN
# 1     2018         1315.00              NaN                 NaN
# 2     2018         1109.00              NaN                 NaN
# 3     2018          189.00              NaN                 NaN
# 4     2018          303.00              NaN                 NaN
# ...    ...             ...              ...                 ...
# 7741  2016           16.90              NaN                 NaN
# 7742  2016           21.91              NaN                 NaN
# 7743  2016           24.95              NaN                 NaN
# 7744  2016           25.40              NaN                 NaN
# 7745  2016           16.32              NaN                 NaN
#
#                                                                                                                                           moneda  \
# 0                                                                                                                      Currency: ALB - Lek (ALL)
# 1                                                                                                                      Currency: ALB - Lek (ALL)
# 2                                                                                                                      Currency: ALB - Lek (ALL)
# 3                                                                                                                      Currency: ALB - Lek (ALL)
# 4                                                                                                                      Currency: ALB - Lek (ALL)
# ...                                                                                                                                          ...
# 7741  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: UKR - Hryvnia (UAH)
# 7742  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: UKR - Hryvnia (UAH)
# 7743  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: UKR - Hryvnia (UAH)
# 7744  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: UKR - Hryvnia (UAH)
# 7745  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: UKR - Hryvnia (UAH)
#
#                                                                                                                                                                                                                                                                        note_source.label
# 0     Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
# 1     Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
# 2     Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
# 3     Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
# 4     Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
# ...                                                                                                                                                                                                                                                                                  ...
# 7741                                                                                                                                                                                                                         Geographical coverage: Total national, excluding some areas
# 7742                                                                                                                                                                                                                         Geographical coverage: Total national, excluding some areas
# 7743                                                                                                                                                                                                                         Geographical coverage: Total national, excluding some areas
# 7744                                                                                                                                                                                                                         Geographical coverage: Total national, excluding some areas
# 7745                                                                                                                                                                                                                         Geographical coverage: Total national, excluding some areas
#
# [7746 rows x 11 columns]

# %% [markdown]
# Cambiar etiquetas de los nombres para que sean más manejables

# %%
df['sexo'] = df['sexo'].replace({
    'Sex: Male': 'Hombres',
    'Sex: Female': 'Mujeres',
    'Sex: Total': 'Total'})

# %%
df
# Out:
#          País  \
# 0     Albania
# 1     Albania
# 2     Albania
# 3     Albania
# 4     Albania
# ...       ...
# 7741  Ukraine
# 7742  Ukraine
# 7743  Ukraine
# 7744  Ukraine
# 7745  Ukraine
#
#                                                                             source.label  \
# 0                                                      ES - Structure of Earnings Survey
# 1                                                      ES - Structure of Earnings Survey
# 2                                                      ES - Structure of Earnings Survey
# 3                                                      ES - Structure of Earnings Survey
# 4                                                      ES - Structure of Earnings Survey
# ...                                                                                  ...
# 7741  ES - Survey on wages of employees by gender, age, education and Occupational group
# 7742  ES - Survey on wages of employees by gender, age, education and Occupational group
# 7743  ES - Survey on wages of employees by gender, age, education and Occupational group
# 7744  ES - Survey on wages of employees by gender, age, education and Occupational group
# 7745  ES - Survey on wages of employees by gender, age, education and Occupational group
#
#                                                                          indicator.label  \
# 0     SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 1     SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 2     SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 3     SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 4     SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# ...                                                                                  ...
# 7741  SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 7742  SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 7743  SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 7744  SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
# 7745  SDG indicator 8.5.1 - Average hourly earnings of employees by sex (Local currency)
#
#          sexo  \
# 0       Total
# 1       Total
# 2       Total
# 3       Total
# 4     Hombres
# ...       ...
# 7741  Mujeres
# 7742  Mujeres
# 7743  Mujeres
# 7744  Mujeres
# 7745  Mujeres
#
#                                                                     nivel_laboral  \
# 0                                                 Occupation (Skill level): Total
# 1                           Occupation (Skill level): Skill levels 3 and 4 ~ high
# 2                                Occupation (Skill level): Skill level 2 ~ medium
# 3                                   Occupation (Skill level): Skill level 1 ~ low
# 4                                                 Occupation (Skill level): Total
# ...                                                                           ...
# 7741                           Occupation (ISCO-08): 5. Service and sales workers
# 7742  Occupation (ISCO-08): 6. Skilled agricultural, forestry and fishery workers
# 7743                    Occupation (ISCO-08): 7. Craft and related trades workers
# 7744         Occupation (ISCO-08): 8. Plant and machine operators, and assemblers
# 7745                              Occupation (ISCO-08): 9. Elementary occupations
#
#        año  prom_ganancias obs_status.label  note_classif.label  \
# 0     2018          293.00              NaN                 NaN
# 1     2018         1315.00              NaN                 NaN
# 2     2018         1109.00              NaN                 NaN
# 3     2018          189.00              NaN                 NaN
# 4     2018          303.00              NaN                 NaN
# ...    ...             ...              ...                 ...
# 7741  2016           16.90              NaN                 NaN
# 7742  2016           21.91              NaN                 NaN
# 7743  2016           24.95              NaN                 NaN
# 7744  2016           25.40              NaN                 NaN
# 7745  2016           16.32              NaN                 NaN
#
#                                                                                                                                           moneda  \
# 0                                                                                                                      Currency: ALB - Lek (ALL)
# 1                                                                                                                      Currency: ALB - Lek (ALL)
# 2                                                                                                                      Currency: ALB - Lek (ALL)
# 3                                                                                                                      Currency: ALB - Lek (ALL)
# 4                                                                                                                      Currency: ALB - Lek (ALL)
# ...                                                                                                                                          ...
# 7741  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: UKR - Hryvnia (UAH)
# 7742  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: UKR - Hryvnia (UAH)
# 7743  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: UKR - Hryvnia (UAH)
# 7744  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: UKR - Hryvnia (UAH)
# 7745  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: UKR - Hryvnia (UAH)
#
#                                                                                                                                                                                                                                                                        note_source.label
# 0     Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
# 1     Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
# 2     Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
# 3     Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
# 4     Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
# ...                                                                                                                                                                                                                                                                                  ...
# 7741                                                                                                                                                                                                                         Geographical coverage: Total national, excluding some areas
# 7742                                                                                                                                                                                                                         Geographical coverage: Total national, excluding some areas
# 7743                                                                                                                                                                                                                         Geographical coverage: Total national, excluding some areas
# 7744                                                                                                                                                                                                                         Geographical coverage: Total national, excluding some areas
# 7745                                                                                                                                                                                                                         Geographical coverage: Total national, excluding some areas
#
# [7746 rows x 11 columns]

# %% [markdown]
# ### Limpieza de variables

# %%
#Voy a eliminar las columnas source.label', 'indicator.label', porque no me dan información relevante y obs_status.label	note_classif.label ya que estan vacías 
df.drop(columns=['source.label','indicator.label','obs_status.label', 'note_classif.label'], inplace=True)

# %%
df
# Out:
#          País     sexo  \
# 0     Albania    Total
# 1     Albania    Total
# 2     Albania    Total
# 3     Albania    Total
# 4     Albania  Hombres
# ...       ...      ...
# 7741  Ukraine  Mujeres
# 7742  Ukraine  Mujeres
# 7743  Ukraine  Mujeres
# 7744  Ukraine  Mujeres
# 7745  Ukraine  Mujeres
#
#                                                                     nivel_laboral  \
# 0                                                 Occupation (Skill level): Total
# 1                           Occupation (Skill level): Skill levels 3 and 4 ~ high
# 2                                Occupation (Skill level): Skill level 2 ~ medium
# 3                                   Occupation (Skill level): Skill level 1 ~ low
# 4                                                 Occupation (Skill level): Total
# ...                                                                           ...
# 7741                           Occupation (ISCO-08): 5. Service and sales workers
# 7742  Occupation (ISCO-08): 6. Skilled agricultural, forestry and fishery workers
# 7743                    Occupation (ISCO-08): 7. Craft and related trades workers
# 7744         Occupation (ISCO-08): 8. Plant and machine operators, and assemblers
# 7745                              Occupation (ISCO-08): 9. Elementary occupations
#
#        año  prom_ganancias  \
# 0     2018          293.00
# 1     2018         1315.00
# 2     2018         1109.00
# 3     2018          189.00
# 4     2018          303.00
# ...    ...             ...
# 7741  2016           16.90
# 7742  2016           21.91
# 7743  2016           24.95
# 7744  2016           25.40
# 7745  2016           16.32
#
#                                                                                                                                           moneda  \
# 0                                                                                                                      Currency: ALB - Lek (ALL)
# 1                                                                                                                      Currency: ALB - Lek (ALL)
# 2                                                                                                                      Currency: ALB - Lek (ALL)
# 3                                                                                                                      Currency: ALB - Lek (ALL)
# 4                                                                                                                      Currency: ALB - Lek (ALL)
# ...                                                                                                                                          ...
# 7741  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: UKR - Hryvnia (UAH)
# 7742  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: UKR - Hryvnia (UAH)
# 7743  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: UKR - Hryvnia (UAH)
# 7744  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: UKR - Hryvnia (UAH)
# 7745  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: UKR - Hryvnia (UAH)
#
#                                                                                                                                                                                                                                                                        note_source.label
# 0     Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
# 1     Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
# 2     Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
# 3     Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
# 4     Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
# ...                                                                                                                                                                                                                                                                                  ...
# 7741                                                                                                                                                                                                                         Geographical coverage: Total national, excluding some areas
# 7742                                                                                                                                                                                                                         Geographical coverage: Total national, excluding some areas
# 7743                                                                                                                                                                                                                         Geographical coverage: Total national, excluding some areas
# 7744                                                                                                                                                                                                                         Geographical coverage: Total national, excluding some areas
# 7745                                                                                                                                                                                                                         Geographical coverage: Total national, excluding some areas
#
# [7746 rows x 7 columns]

# %% [markdown]
# Viendo el dataframe se puede observar que los valores estan medidos por diferentes monedas

# %%
df['moneda'].values
# Out:
# ['Currency: ALB - Lek (ALL)', 'Currency: ALB - Lek (ALL)', 'Currency: ALB - Lek (ALL)', 'Currency: ALB - Lek (ALL)', 'Currency: ALB - Lek (ALL)', ..., 'Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: UKR - Hryvnia (UAH)', 'Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: UKR - Hryvnia (UAH)', 'Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: UKR - Hryvnia (UAH)', 'Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: UKR - Hryvnia (UAH)', 'Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: UKR - Hryvnia (UAH)']
# Length: 7746
# Categories (52, object): ['Central tendency measure: Mean or mean of the midpoints of the intervals provided | Currency: BIH - Marka (BAM)', 'Central tendency measure: Mean or mean of the midpoints of the intervals provided | Currency: BIH - Marka (BAM) | Break in series: Methodology revised', 'Currency: ALB - Lek (ALL)', 'Currency: AUT - Euro (EUR)', ..., 'Working time arrangement coverage: Full-time equivalents | Currency: LTU - Euro (EUR)', 'Working time arrangement coverage: Full-time equivalents | Currency: SWE - Swedish krona (SEK)', 'Working time arrangement coverage: Full-time workers | Currency: CZE - Koruna (CZK)', 'Working time arrangement coverage: Full-time workers | Currency: HUN - Forint (HUF)']

# %% [markdown]
# Por lo que se tomara una decisión sobre que hacer con los datos y se eligirá aquellos países que estén en la zona Euro

# %% [markdown]
# ## 3. Identificar valores duplicados o errores evidentes

# %% [markdown]
# ### Duplicados exacto

# %%
# Identificar duplicados exactos
duplicados_exactos = df[df.duplicated()]

# Número de duplicados exactos
n_duplicados_exactos = len(duplicados_exactos)

duplicados_exactos.head()
# Out:
# Empty DataFrame
# Columns: [País, sexo, nivel_laboral, año, prom_ganancias, moneda, note_source.label]
# Index: []

# %% [markdown]
# ### Duplicados parciales

# %%
# Identificar duplicados parciales basados en ciertas columnas
columnas_a_verificar = ['País', 'año', 'sexo']
duplicados_parciales = df[df.duplicated(subset=columnas_a_verificar)]

# Número de duplicados parciales
len(duplicados_parciales)

duplicados_parciales.head()
# Identificar errores evidentes en los datos (problemas de codificación y parsing)
# Comprobando si hay valores mal decodificados (UTF-8 o ASCII)
# Ver si alguna columna contiene caracteres extraños no imprimibles
errores_codificacion = df.applymap(lambda x: isinstance(x, str) and not x.isprintable())

# Resumen de resultados
{
    "Duplicados Exactos": len(duplicados_exactos),
    "Duplicados Parciales": len(duplicados_parciales),
    "Errores de Codificación": errores_codificacion.any().sum()  # Total de columnas con errores
}
# Out:
# {'Duplicados Exactos': 0,
#  'Duplicados Parciales': 7224,
#  'Errores de Codificación': np.int64(0)}

# %% [markdown]
# ### Ver Valores perdidos

# %% [markdown]
# Se puede observar 56 valores perdidos en la columna obs_Value que se tiene que ver el porque

# %%
filas_con_perdidos = df[df.isna().any(axis=1)]
filas_con_perdidos
# Out:
#                                                       País     sexo  \
# 392                                 Bosnia and Herzegovina  Mujeres
# 425                                 Bosnia and Herzegovina  Mujeres
# 584                                 Bosnia and Herzegovina  Mujeres
# 613                                 Bosnia and Herzegovina  Mujeres
# 617                                 Bosnia and Herzegovina  Mujeres
# 632                                 Bosnia and Herzegovina  Mujeres
# 661                                 Bosnia and Herzegovina  Mujeres
# 665                                 Bosnia and Herzegovina  Mujeres
# 680                                 Bosnia and Herzegovina  Mujeres
# 709                                 Bosnia and Herzegovina  Mujeres
# 713                                 Bosnia and Herzegovina  Mujeres
# 728                                 Bosnia and Herzegovina  Mujeres
# 757                                 Bosnia and Herzegovina  Mujeres
# 761                                 Bosnia and Herzegovina  Mujeres
# 886                                            Switzerland  Mujeres
# 937                                            Switzerland  Mujeres
# 988                                            Switzerland  Mujeres
# 1039                                           Switzerland  Mujeres
# 1090                                           Switzerland  Mujeres
# 1141                                           Switzerland  Mujeres
# 1345                                           Switzerland  Mujeres
# 3160  United Kingdom of Great Britain and Northern Ireland  Mujeres
# 3188  United Kingdom of Great Britain and Northern Ireland    Total
# 3200  United Kingdom of Great Britain and Northern Ireland  Hombres
# 3211  United Kingdom of Great Britain and Northern Ireland  Mujeres
# 3212  United Kingdom of Great Britain and Northern Ireland  Mujeres
# 3227  United Kingdom of Great Britain and Northern Ireland  Mujeres
# 3251  United Kingdom of Great Britain and Northern Ireland  Hombres
# 3262  United Kingdom of Great Britain and Northern Ireland  Mujeres
# 3263  United Kingdom of Great Britain and Northern Ireland  Mujeres
# 3302  United Kingdom of Great Britain and Northern Ireland  Hombres
# 3314  United Kingdom of Great Britain and Northern Ireland  Mujeres
# 3509  United Kingdom of Great Britain and Northern Ireland  Mujeres
# 3650  United Kingdom of Great Britain and Northern Ireland  Hombres
# 5229                                   Republic of Moldova    Total
# 5234                                   Republic of Moldova  Hombres
# 5239                                   Republic of Moldova  Mujeres
# 5250                                   Republic of Moldova    Total
# 5261                                   Republic of Moldova  Hombres
# 5272                                   Republic of Moldova  Mujeres
# 5277                                   Republic of Moldova    Total
# 5282                                   Republic of Moldova  Hombres
# 5287                                   Republic of Moldova  Mujeres
# 5298                                   Republic of Moldova    Total
# 5309                                   Republic of Moldova  Hombres
# 5320                                   Republic of Moldova  Mujeres
# 5335                                   Republic of Moldova  Mujeres
# 5368                                   Republic of Moldova  Mujeres
# 5383                                   Republic of Moldova  Mujeres
# 5416                                   Republic of Moldova  Mujeres
# 5431                                   Republic of Moldova  Mujeres
# 5464                                   Republic of Moldova  Mujeres
# 5479                                   Republic of Moldova  Mujeres
# 5512                                   Republic of Moldova  Mujeres
# 5623                                   Republic of Moldova  Mujeres
# 5656                                   Republic of Moldova  Mujeres
#
#                                                                     nivel_laboral  \
# 392                            Occupation (Skill level): Not elsewhere classified
# 425                             Occupation (ISCO-08): 0. Armed forces occupations
# 584                            Occupation (Skill level): Not elsewhere classified
# 613   Occupation (ISCO-08): 6. Skilled agricultural, forestry and fishery workers
# 617                             Occupation (ISCO-08): 0. Armed forces occupations
# 632                            Occupation (Skill level): Not elsewhere classified
# 661   Occupation (ISCO-08): 6. Skilled agricultural, forestry and fishery workers
# 665                             Occupation (ISCO-08): 0. Armed forces occupations
# 680                            Occupation (Skill level): Not elsewhere classified
# 709   Occupation (ISCO-08): 6. Skilled agricultural, forestry and fishery workers
# 713                             Occupation (ISCO-08): 0. Armed forces occupations
# 728                            Occupation (Skill level): Not elsewhere classified
# 757   Occupation (ISCO-08): 6. Skilled agricultural, forestry and fishery workers
# 761                             Occupation (ISCO-08): 0. Armed forces occupations
# 886                             Occupation (ISCO-08): 0. Armed forces occupations
# 937                             Occupation (ISCO-08): 0. Armed forces occupations
# 988                             Occupation (ISCO-08): 0. Armed forces occupations
# 1039                            Occupation (ISCO-08): 0. Armed forces occupations
# 1090                            Occupation (ISCO-08): 0. Armed forces occupations
# 1141                            Occupation (ISCO-08): 0. Armed forces occupations
# 1345                            Occupation (ISCO-08): 0. Armed forces occupations
# 3160                            Occupation (ISCO-08): 0. Armed forces occupations
# 3188                            Occupation (ISCO-08): X. Not elsewhere classified
# 3200                            Occupation (ISCO-08): X. Not elsewhere classified
# 3211                            Occupation (ISCO-08): 0. Armed forces occupations
# 3212                            Occupation (ISCO-08): X. Not elsewhere classified
# 3227                           Occupation (Skill level): Not elsewhere classified
# 3251                            Occupation (ISCO-08): X. Not elsewhere classified
# 3262                            Occupation (ISCO-08): 0. Armed forces occupations
# 3263                            Occupation (ISCO-08): X. Not elsewhere classified
# 3302                            Occupation (ISCO-08): X. Not elsewhere classified
# 3314                            Occupation (ISCO-08): X. Not elsewhere classified
# 3509                            Occupation (ISCO-08): X. Not elsewhere classified
# 3650                            Occupation (ISCO-08): X. Not elsewhere classified
# 5229                           Occupation (Skill level): Not elsewhere classified
# 5234                           Occupation (Skill level): Not elsewhere classified
# 5239                           Occupation (Skill level): Not elsewhere classified
# 5250                            Occupation (ISCO-08): 0. Armed forces occupations
# 5261                            Occupation (ISCO-08): 0. Armed forces occupations
# 5272                            Occupation (ISCO-08): 0. Armed forces occupations
# 5277                           Occupation (Skill level): Not elsewhere classified
# 5282                           Occupation (Skill level): Not elsewhere classified
# 5287                           Occupation (Skill level): Not elsewhere classified
# 5298                            Occupation (ISCO-08): 0. Armed forces occupations
# 5309                            Occupation (ISCO-08): 0. Armed forces occupations
# 5320                            Occupation (ISCO-08): 0. Armed forces occupations
# 5335                           Occupation (Skill level): Not elsewhere classified
# 5368                            Occupation (ISCO-08): 0. Armed forces occupations
# 5383                           Occupation (Skill level): Not elsewhere classified
# 5416                            Occupation (ISCO-08): 0. Armed forces occupations
# 5431                           Occupation (Skill level): Not elsewhere classified
# 5464                            Occupation (ISCO-08): 0. Armed forces occupations
# 5479                           Occupation (Skill level): Not elsewhere classified
# 5512                            Occupation (ISCO-08): 0. Armed forces occupations
# 5623                           Occupation (Skill level): Not elsewhere classified
# 5656                            Occupation (ISCO-08): 0. Armed forces occupations
#
#        año  prom_ganancias  \
# 392   2023             NaN
# 425   2023             NaN
# 584   2016             NaN
# 613   2016             NaN
# 617   2016             NaN
# 632   2015             NaN
# 661   2015             NaN
# 665   2015             NaN
# 680   2014             NaN
# 709   2014             NaN
# 713   2014             NaN
# 728   2013             NaN
# 757   2013             NaN
# 761   2013             NaN
# 886   2023             NaN
# 937   2022             NaN
# 988   2021             NaN
# 1039  2020             NaN
# 1090  2019             NaN
# 1141  2018             NaN
# 1345  2014             NaN
# 3160  2023             NaN
# 3188  2022             NaN
# 3200  2022             NaN
# 3211  2022             NaN
# 3212  2022             NaN
# 3227  2021             NaN
# 3251  2021             NaN
# 3262  2021             NaN
# 3263  2021             NaN
# 3302  2020             NaN
# 3314  2020             NaN
# 3509  2016             NaN
# 3650  2013             NaN
# 5229  2023             NaN
# 5234  2023             NaN
# 5239  2023             NaN
# 5250  2023             NaN
# 5261  2023             NaN
# 5272  2023             NaN
# 5277  2022             NaN
# 5282  2022             NaN
# 5287  2022             NaN
# 5298  2022             NaN
# 5309  2022             NaN
# 5320  2022             NaN
# 5335  2021             NaN
# 5368  2021             NaN
# 5383  2020             NaN
# 5416  2020             NaN
# 5431  2019             NaN
# 5464  2019             NaN
# 5479  2018             NaN
# 5512  2018             NaN
# 5623  2015             NaN
# 5656  2015             NaN
#
#                                                                                                                                                       moneda  \
# 392   Central tendency measure: Mean or mean of the midpoints of the intervals provided | Currency: BIH - Marka (BAM) | Break in series: Methodology revised
# 425   Central tendency measure: Mean or mean of the midpoints of the intervals provided | Currency: BIH - Marka (BAM) | Break in series: Methodology revised
# 584                                          Central tendency measure: Mean or mean of the midpoints of the intervals provided | Currency: BIH - Marka (BAM)
# 613                                          Central tendency measure: Mean or mean of the midpoints of the intervals provided | Currency: BIH - Marka (BAM)
# 617                                          Central tendency measure: Mean or mean of the midpoints of the intervals provided | Currency: BIH - Marka (BAM)
# 632                                          Central tendency measure: Mean or mean of the midpoints of the intervals provided | Currency: BIH - Marka (BAM)
# 661                                          Central tendency measure: Mean or mean of the midpoints of the intervals provided | Currency: BIH - Marka (BAM)
# 665                                          Central tendency measure: Mean or mean of the midpoints of the intervals provided | Currency: BIH - Marka (BAM)
# 680                                          Central tendency measure: Mean or mean of the midpoints of the intervals provided | Currency: BIH - Marka (BAM)
# 709                                          Central tendency measure: Mean or mean of the midpoints of the intervals provided | Currency: BIH - Marka (BAM)
# 713                                          Central tendency measure: Mean or mean of the midpoints of the intervals provided | Currency: BIH - Marka (BAM)
# 728                                          Central tendency measure: Mean or mean of the midpoints of the intervals provided | Currency: BIH - Marka (BAM)
# 757                                          Central tendency measure: Mean or mean of the midpoints of the intervals provided | Currency: BIH - Marka (BAM)
# 761                                          Central tendency measure: Mean or mean of the midpoints of the intervals provided | Currency: BIH - Marka (BAM)
# 886                                                                                                                               Currency: CHE - Euro (EUR)
# 937                                                                                                                               Currency: CHE - Euro (EUR)
# 988                                                                                                                               Currency: CHE - Euro (EUR)
# 1039                                                                                                                              Currency: CHE - Euro (EUR)
# 1090                                                                                                                              Currency: CHE - Euro (EUR)
# 1141                                                                                                                              Currency: CHE - Euro (EUR)
# 1345                                                                                                                              Currency: CHE - Euro (EUR)
# 3160                                                                                                                              Currency: GBR - Euro (EUR)
# 3188                                                                                                                              Currency: GBR - Euro (EUR)
# 3200                                                                                                                              Currency: GBR - Euro (EUR)
# 3211                                                                                                                              Currency: GBR - Euro (EUR)
# 3212                                                                                                                              Currency: GBR - Euro (EUR)
# 3227                                                                                                                              Currency: GBR - Euro (EUR)
# 3251                                                                                                                              Currency: GBR - Euro (EUR)
# 3262                                                                                                                              Currency: GBR - Euro (EUR)
# 3263                                                                                                                              Currency: GBR - Euro (EUR)
# 3302                                                                                                                              Currency: GBR - Euro (EUR)
# 3314                                                                                                                              Currency: GBR - Euro (EUR)
# 3509                                                                                                                              Currency: GBR - Euro (EUR)
# 3650                                                                                                                              Currency: GBR - Euro (EUR)
# 5229                                                                                                                      Currency: MDA - Moldovan leu (MDL)
# 5234                                                                                                                      Currency: MDA - Moldovan leu (MDL)
# 5239                                                                                                                      Currency: MDA - Moldovan leu (MDL)
# 5250                                                                                                                      Currency: MDA - Moldovan leu (MDL)
# 5261                                                                                                                      Currency: MDA - Moldovan leu (MDL)
# 5272                                                                                                                      Currency: MDA - Moldovan leu (MDL)
# 5277                                                                                                                      Currency: MDA - Moldovan leu (MDL)
# 5282                                                                                                                      Currency: MDA - Moldovan leu (MDL)
# 5287                                                                                                                      Currency: MDA - Moldovan leu (MDL)
# 5298                                                                                                                      Currency: MDA - Moldovan leu (MDL)
# 5309                                                                                                                      Currency: MDA - Moldovan leu (MDL)
# 5320                                                                                                                      Currency: MDA - Moldovan leu (MDL)
# 5335                                                                                                                      Currency: MDA - Moldovan leu (MDL)
# 5368                                                                                                                      Currency: MDA - Moldovan leu (MDL)
# 5383                                                                                                                      Currency: MDA - Moldovan leu (MDL)
# 5416                                                                                                                      Currency: MDA - Moldovan leu (MDL)
# 5431                                                                                                                      Currency: MDA - Moldovan leu (MDL)
# 5464                                                                                                                      Currency: MDA - Moldovan leu (MDL)
# 5479                                                                                                                      Currency: MDA - Moldovan leu (MDL)
# 5512                                                                                                                      Currency: MDA - Moldovan leu (MDL)
# 5623                                                                                                                      Currency: MDA - Moldovan leu (MDL)
# 5656                                                                                                                      Currency: MDA - Moldovan leu (MDL)
#
#                                        note_source.label
# 392   Repository: ILO-STATISTICS - Micro data processing
# 425   Repository: ILO-STATISTICS - Micro data processing
# 584   Repository: ILO-STATISTICS - Micro data processing
# 613   Repository: ILO-STATISTICS - Micro data processing
# 617   Repository: ILO-STATISTICS - Micro data processing
# 632   Repository: ILO-STATISTICS - Micro data processing
# 661   Repository: ILO-STATISTICS - Micro data processing
# 665   Repository: ILO-STATISTICS - Micro data processing
# 680   Repository: ILO-STATISTICS - Micro data processing
# 709   Repository: ILO-STATISTICS - Micro data processing
# 713   Repository: ILO-STATISTICS - Micro data processing
# 728   Repository: ILO-STATISTICS - Micro data processing
# 757   Repository: ILO-STATISTICS - Micro data processing
# 761   Repository: ILO-STATISTICS - Micro data processing
# 886   Repository: ILO-STATISTICS - Micro data processing
# 937   Repository: ILO-STATISTICS - Micro data processing
# 988   Repository: ILO-STATISTICS - Micro data processing
# 1039  Repository: ILO-STATISTICS - Micro data processing
# 1090  Repository: ILO-STATISTICS - Micro data processing
# 1141  Repository: ILO-STATISTICS - Micro data processing
# 1345  Repository: ILO-STATISTICS - Micro data processing
# 3160  Repository: ILO-STATISTICS - Micro data processing
# 3188  Repository: ILO-STATISTICS - Micro data processing
# 3200  Repository: ILO-STATISTICS - Micro data processing
# 3211  Repository: ILO-STATISTICS - Micro data processing
# 3212  Repository: ILO-STATISTICS - Micro data processing
# 3227  Repository: ILO-STATISTICS - Micro data processing
# 3251  Repository: ILO-STATISTICS - Micro data processing
# 3262  Repository: ILO-STATISTICS - Micro data processing
# 3263  Repository: ILO-STATISTICS - Micro data processing
# 3302  Repository: ILO-STATISTICS - Micro data processing
# 3314  Repository: ILO-STATISTICS - Micro data processing
# 3509  Repository: ILO-STATISTICS - Micro data processing
# 3650  Repository: ILO-STATISTICS - Micro data processing
# 5229  Repository: ILO-STATISTICS - Micro data processing
# 5234  Repository: ILO-STATISTICS - Micro data processing
# 5239  Repository: ILO-STATISTICS - Micro data processing
# 5250  Repository: ILO-STATISTICS - Micro data processing
# 5261  Repository: ILO-STATISTICS - Micro data processing
# 5272  Repository: ILO-STATISTICS - Micro data processing
# 5277  Repository: ILO-STATISTICS - Micro data processing
# 5282  Repository: ILO-STATISTICS - Micro data processing
# 5287  Repository: ILO-STATISTICS - Micro data processing
# 5298  Repository: ILO-STATISTICS - Micro data processing
# 5309  Repository: ILO-STATISTICS - Micro data processing
# 5320  Repository: ILO-STATISTICS - Micro data processing
# 5335  Repository: ILO-STATISTICS - Micro data processing
# 5368  Repository: ILO-STATISTICS - Micro data processing
# 5383  Repository: ILO-STATISTICS - Micro data processing
# 5416  Repository: ILO-STATISTICS - Micro data processing
# 5431  Repository: ILO-STATISTICS - Micro data processing
# 5464  Repository: ILO-STATISTICS - Micro data processing
# 5479  Repository: ILO-STATISTICS - Micro data processing
# 5512  Repository: ILO-STATISTICS - Micro data processing
# 5623  Repository: ILO-STATISTICS - Micro data processing
# 5656  Repository: ILO-STATISTICS - Micro data processing

# %%
df[df['País']=='Spain']
# Out:
#        País     sexo  \
# 1884  Spain    Total
# 1885  Spain    Total
# 1886  Spain    Total
# 1887  Spain    Total
# 1888  Spain  Hombres
# ...     ...      ...
# 2257  Spain  Mujeres
# 2258  Spain  Mujeres
# 2259  Spain  Mujeres
# 2260  Spain  Mujeres
# 2261  Spain  Mujeres
#
#                                                                     nivel_laboral  \
# 1884                                              Occupation (Skill level): Total
# 1885                        Occupation (Skill level): Skill levels 3 and 4 ~ high
# 1886                             Occupation (Skill level): Skill level 2 ~ medium
# 1887                                Occupation (Skill level): Skill level 1 ~ low
# 1888                                              Occupation (Skill level): Total
# ...                                                                           ...
# 2257                           Occupation (ISCO-08): 5. Service and sales workers
# 2258  Occupation (ISCO-08): 6. Skilled agricultural, forestry and fishery workers
# 2259                    Occupation (ISCO-08): 7. Craft and related trades workers
# 2260         Occupation (ISCO-08): 8. Plant and machine operators, and assemblers
# 2261                              Occupation (ISCO-08): 9. Elementary occupations
#
#        año  prom_ganancias  \
# 1884  2021            17.0
# 1885  2021            79.0
# 1886  2021            68.0
# 1887  2021            11.0
# 1888  2021            17.0
# ...    ...             ...
# 2257  2013            10.0
# 2258  2013             0.0
# 2259  2013            10.0
# 2260  2013            11.0
# 2261  2013             9.0
#
#                                                                                                                                        moneda  \
# 1884  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: ESP - Euro (EUR)
# 1885  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: ESP - Euro (EUR)
# 1886  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: ESP - Euro (EUR)
# 1887  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: ESP - Euro (EUR)
# 1888  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: ESP - Euro (EUR)
# ...                                                                                                                                       ...
# 2257  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: ESP - Euro (EUR)
# 2258  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: ESP - Euro (EUR)
# 2259  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: ESP - Euro (EUR)
# 2260  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: ESP - Euro (EUR)
# 2261  Job coverage: Main job currently held | Working time arrangement coverage: Full-time and part time workers | Currency: ESP - Euro (EUR)
#
#                                                                                                                                                                                                note_source.label
# 1884  Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Reference group coverage: Employees
# 1885  Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Reference group coverage: Employees
# 1886  Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Reference group coverage: Employees
# 1887  Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Reference group coverage: Employees
# 1888  Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Reference group coverage: Employees
# ...                                                                                                                                                                                                          ...
# 2257  Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Reference group coverage: Employees
# 2258  Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Reference group coverage: Employees
# 2259  Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Reference group coverage: Employees
# 2260  Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Reference group coverage: Employees
# 2261  Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Reference group coverage: Employees
#
# [378 rows x 7 columns]

# %% [markdown]
# aqui se puede observar los países donde falta los datos, en otros faltan años
# - Eliminar esos países
# - proporcionar un tratamiento de datos

# %% [markdown]
# ## ocupación

# %%
df['nivel_laboral'].unique()
# Out:
# ['Occupation (Skill level): Total', 'Occupation (Skill level): Skill levels 3 and 4 ~ high', 'Occupation (Skill level): Skill level 2 ~ medium', 'Occupation (Skill level): Skill level 1 ~ low', 'Occupation (ISCO-08): Total', ..., 'Occupation (ISCO-88): 7. Craft and related trades workers', 'Occupation (ISCO-88): 8. Plant and machine operators and assemblers', 'Occupation (ISCO-88): 9. Elementary occupations', 'Occupation (ISCO-08): X. Not elsewhere classified', 'Occupation (ISCO-88): 0. Armed forces']
# Length: 28
# Categories (28, object): ['Occupation (ISCO-08): 0. Armed forces occupations', 'Occupation (ISCO-08): 1. Managers', 'Occupation (ISCO-08): 2. Professionals', 'Occupation (ISCO-08): 3. Technicians and associate professionals', ..., 'Occupation (Skill level): Skill level 1 ~ low', 'Occupation (Skill level): Skill level 2 ~ medium', 'Occupation (Skill level): Skill levels 3 and 4 ~ high', 'Occupation (Skill level): Total']

# %%
len(df['nivel_laboral'].unique())
# Out:
# 28

# %%
filtered_data_isco_08 = df[df['nivel_laboral'].str.contains('ISCO-08)', regex=False)]

# %%
filtered_data_isco_08.head()
# Out:
#        País   sexo  \
# 12  Albania  Total
# 13  Albania  Total
# 14  Albania  Total
# 15  Albania  Total
# 16  Albania  Total
#
#                                                        nivel_laboral   año  \
# 12                                       Occupation (ISCO-08): Total  2018
# 13                                 Occupation (ISCO-08): 1. Managers  2018
# 14                            Occupation (ISCO-08): 2. Professionals  2018
# 15  Occupation (ISCO-08): 3. Technicians and associate professionals  2018
# 16                 Occupation (ISCO-08): 4. Clerical support workers  2018
#
#     prom_ganancias                     moneda  \
# 12           293.0  Currency: ALB - Lek (ALL)
# 13           568.0  Currency: ALB - Lek (ALL)
# 14           399.0  Currency: ALB - Lek (ALL)
# 15           348.0  Currency: ALB - Lek (ALL)
# 16           333.0  Currency: ALB - Lek (ALL)
#
#                                                                                                                                                                                                                                                                      note_source.label
# 12  Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
# 13  Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
# 14  Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
# 15  Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
# 16  Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees

# %%
filtered_data_isco_08['nivel_laboral'].value_counts()
# Out:
# nivel_laboral
# Occupation (ISCO-08): Total                                                    516
# Occupation (ISCO-08): 1. Managers                                              504
# Occupation (ISCO-08): 3. Technicians and associate professionals               504
# Occupation (ISCO-08): 2. Professionals                                         504
# Occupation (ISCO-08): 9. Elementary occupations                                504
# Occupation (ISCO-08): 4. Clerical support workers                              504
# Occupation (ISCO-08): 7. Craft and related trades workers                      504
# Occupation (ISCO-08): 5. Service and sales workers                             504
# Occupation (ISCO-08): 8. Plant and machine operators, and assemblers           502
# Occupation (ISCO-08): 6. Skilled agricultural, forestry and fishery workers    449
# Occupation (ISCO-08): 0. Armed forces occupations                              288
# Occupation (ISCO-08): X. Not elsewhere classified                              159
# Occupation (ISCO-88): 0. Armed forces                                            0
# Occupation (ISCO-88): 1. Legislators, senior officials and managers              0
# Occupation (ISCO-88): 2. Professionals                                           0
# Occupation (ISCO-88): 3. Technicians and associate professionals                 0
# Occupation (ISCO-88): 4. Clerks                                                  0
# Occupation (ISCO-88): 5. Service workers and shop and market sales workers       0
# Occupation (ISCO-88): 6. Skilled agricultural and fishery workers                0
# Occupation (ISCO-88): 7. Craft and related trades workers                        0
# Occupation (ISCO-88): 8. Plant and machine operators and assemblers              0
# Occupation (ISCO-88): 9. Elementary occupations                                  0
# Occupation (ISCO-88): Total                                                      0
# Occupation (Skill level): Not elsewhere classified                               0
# Occupation (Skill level): Skill level 1 ~ low                                    0
# Occupation (Skill level): Skill level 2 ~ medium                                 0
# Occupation (Skill level): Skill levels 3 and 4 ~ high                            0
# Occupation (Skill level): Total                                                  0
# Name: count, dtype: int64

# %% [markdown]
# Se ha hecho un filtrado para seleccionar que tipo de Indicador de trabajadores se iba a utilizar para el analisis. Estaba compuesto por dos índices ISCO-08 y ISCO-88. Después de documentarme en la plataforma de datos estadisticos de donde provienen los datos, he decidido elegir ISCO-08 debido a que es la más reciente. Por otro lado, se cambiará las etiquetas para que sea más sencillo a la hora de graficar

# %%
filtered_data_isco_08['nivel_laboral'] = filtered_data_isco_08['nivel_laboral'].replace({
    'Occupation (ISCO-08): Total': 'Total',
    'Occupation (ISCO-08): 1. Managers': 'Directores y gerentes',
    'Occupation (ISCO-08): 2. Professionals': 'Profesionales científicos e intelectuales',
    'Occupation (ISCO-08): 3. Technicians and associate professionals': 'Técnicos y profesionales de nivel medio',
    'Occupation (ISCO-08): 4. Clerical support workers': 'Personal de apoyo administrativo',
    'Occupation (ISCO-08): 5. Service and sales workers': 'Trabajadores de los servicios y vendedores de comercios y mercados',
    'Occupation (ISCO-08): 6. Skilled agricultural, forestry and fishery workers': 'Agricultores y trabajadores calificados agropecuarios, forestales y pesqueros',
    'Occupation (ISCO-08): 7. Craft and related trades workers': 'Oficiales, operarios y artesanos de artes mecánicas y de otros oficios',
    'Occupation (ISCO-08): 8. Plant and machine operators, and assemblers': 'Operadores de instalaciones y máquinas y ensambladores',
    'Occupation (ISCO-08): 9. Elementary occupations': 'Ocupaciones elementales',
    'Occupation (ISCO-08): 0. Armed forces occupations': 'Ocupaciones militares',
    'Occupation (ISCO-08): X. Not elsewhere classified': 'No clasificado'
    })

# %%
print(filtered_data_isco_08['nivel_laboral'].unique())
# Out:
# ['Total', 'Directores y gerentes', 'Profesionales científicos e intelectuales', 'Técnicos y profesionales de nivel medio', 'Personal de apoyo administrativo', ..., 'Oficiales, operarios y artesanos de artes mecánicas y de otros oficios', 'Operadores de instalaciones y máquinas y ensambladores', 'Ocupaciones elementales', 'Ocupaciones militares', 'No clasificado']
# Length: 12
# Categories (27, object): ['Ocupaciones militares', 'Directores y gerentes', 'Profesionales científicos e intelectuales', 'Técnicos y profesionales de nivel medio', ..., 'Occupation (Skill level): Skill level 1 ~ low', 'Occupation (Skill level): Skill level 2 ~ medium', 'Occupation (Skill level): Skill levels 3 and 4 ~ high', 'Occupation (Skill level): Total']

# %% [markdown]
# ## Países

# %%
df.head(), df.columns
# Out:
# (      País     sexo                                          nivel_laboral  \
#  0  Albania    Total                        Occupation (Skill level): Total
#  1  Albania    Total  Occupation (Skill level): Skill levels 3 and 4 ~ high
#  2  Albania    Total       Occupation (Skill level): Skill level 2 ~ medium
#  3  Albania    Total          Occupation (Skill level): Skill level 1 ~ low
#  4  Albania  Hombres                        Occupation (Skill level): Total
#
#      año  prom_ganancias                     moneda  \
#  0  2018           293.0  Currency: ALB - Lek (ALL)
#  1  2018          1315.0  Currency: ALB - Lek (ALL)
#  2  2018          1109.0  Currency: ALB - Lek (ALL)
#  3  2018           189.0  Currency: ALB - Lek (ALL)
#  4  2018           303.0  Currency: ALB - Lek (ALL)
#
#                                                                                                                                                                                                                                                                      note_source.label
#  0  Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
#  1  Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
#  2  Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
#  3  Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees
#  4  Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Establishment size coverage: All establishments with at least 10 employees  ,
#  Index(['País', 'sexo', 'nivel_laboral', 'año', 'prom_ganancias', 'moneda',
#         'note_source.label'],
#        dtype='object'))

# %%
eu_data= filtered_data_isco_08[filtered_data_isco_08['moneda'].str.contains('Euro', regex=False)]

# %% [markdown]
# Como hay diferentes monedas y es imposible comparar por el diferente valor que tiene cada moneda voy a realizar un filtrado con los países que tienen euros.
#
#      (Alemania, Austria, Bélgica,Chipre, Eslovaquia, Eslovenia, España, Estonia, Finlandia, Francia, Grecia, Irlanda, Italia,Letonia, Lituania, Luxemburgo, Malta, Países Bajos y Portugal.)

# %%
print(eu_data.isnull().sum())
# Out:
# País                  0
# sexo                  0
# nivel_laboral         0
# año                   0
# prom_ganancias       19
# moneda                0
# note_source.label     0
# dtype: int64

# %%
eu_data.head()
# Out:
#        País   sexo                               nivel_laboral   año  \
# 51  Austria  Total                                       Total  2018
# 52  Austria  Total                       Directores y gerentes  2018
# 53  Austria  Total  Profesionales científicos e intelectuales  2018
# 54  Austria  Total    Técnicos y profesionales de nivel medio  2018
# 55  Austria  Total            Personal de apoyo administrativo  2018
#
#     prom_ganancias  \
# 51           17.42
# 52           36.58
# 53           24.81
# 54           19.93
# 55           16.48
#
#                                                                                              moneda  \
# 51  Working time arrangement coverage: Full-time and part time workers | Currency: AUT - Euro (EUR)
# 52  Working time arrangement coverage: Full-time and part time workers | Currency: AUT - Euro (EUR)
# 53  Working time arrangement coverage: Full-time and part time workers | Currency: AUT - Euro (EUR)
# 54  Working time arrangement coverage: Full-time and part time workers | Currency: AUT - Euro (EUR)
# 55  Working time arrangement coverage: Full-time and part time workers | Currency: AUT - Euro (EUR)
#
#                                                                                                                                                                                                                                                                                                            note_source.label
# 51  Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Reference group coverage: Employees | Establishment size coverage: All establishments with at least 10 employees
# 52  Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Reference group coverage: Employees | Establishment size coverage: All establishments with at least 10 employees
# 53  Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Reference group coverage: Employees | Establishment size coverage: All establishments with at least 10 employees
# 54  Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Reference group coverage: Employees | Establishment size coverage: All establishments with at least 10 employees
# 55  Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Reference group coverage: Employees | Establishment size coverage: All establishments with at least 10 employees

# %% [markdown]
# ### Años

# %%
years_by_country = eu_data.groupby('País')['año'].unique()
print(years_by_country)
# Out:
# País
# Albania                                                                                                                 []
# Austria                                                                                                       [2018, 2014]
# Belarus                                                                                                                 []
# Belgium                                                                                     [2018, 2017, 2016, 2015, 2014]
# Bosnia and Herzegovina                                                                                                  []
# Bulgaria                                                                                                            [2014]
# Croatia                                                                                                                 []
# Czechia                                                                                                                 []
# Denmark                                                                                                             [2014]
# Estonia                                                                                                       [2018, 2014]
# Finland                                                                         [2022, 2021, 2020, 2017, 2016, 2014, 2013]
# France                                                                    [2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013]
# Germany                                                                                                       [2018, 2014]
# Greece                                                                          [2020, 2019, 2018, 2017, 2016, 2015, 2014]
# Hungary                                                                                                             [2014]
# Iceland                                                                                                                 []
# Ireland                                                                                                       [2018, 2014]
# Italy                                                                           [2020, 2019, 2018, 2017, 2016, 2015, 2014]
# Latvia                                                                                                        [2018, 2014]
# Lithuania                                                                                                     [2018, 2014]
# Luxembourg                                                                                                    [2018, 2014]
# Malta                                                                                                         [2018, 2014]
# Montenegro                                                                                                          [2014]
# Netherlands                                                                                                   [2018, 2014]
# North Macedonia                                                                                                         []
# Norway                                                                                                              [2014]
# Poland                                                                                                              [2014]
# Portugal                                                [2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013]
# Republic of Moldova                                                                                                     []
# Romania                                                                                                             [2014]
# Russian Federation                                                                                                      []
# Serbia                                                                                                              [2014]
# Slovakia                                                                              [2022, 2021, 2020, 2019, 2015, 2014]
# Slovenia                                                                                                      [2018, 2014]
# Spain                                                               [2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013]
# Sweden                                                                                                              [2014]
# Switzerland                                             [2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013]
# Ukraine                                                                                                                 []
# United Kingdom of Great Britain and Northern Ireland          [2023, 2022, 2021, 2020, 2018, 2017, 2016, 2015, 2014, 2013]
# Name: año, dtype: object

# %%
eu_data.head(10)
# Out:
#        País     sexo  \
# 51  Austria    Total
# 52  Austria    Total
# 53  Austria    Total
# 54  Austria    Total
# 55  Austria    Total
# 56  Austria    Total
# 57  Austria    Total
# 58  Austria    Total
# 59  Austria    Total
# 60  Austria  Hombres
#
#                                                               nivel_laboral  \
# 51                                                                    Total
# 52                                                    Directores y gerentes
# 53                               Profesionales científicos e intelectuales
# 54                                 Técnicos y profesionales de nivel medio
# 55                                         Personal de apoyo administrativo
# 56       Trabajadores de los servicios y vendedores de comercios y mercados
# 57  Oficiales, operarios y artesanos de artes mecánicas y de otros oficios
# 58                  Operadores de instalaciones y máquinas y ensambladores
# 59                                                  Ocupaciones elementales
# 60                                                                    Total
#
#      año  prom_ganancias  \
# 51  2018           17.42
# 52  2018           36.58
# 53  2018           24.81
# 54  2018           19.93
# 55  2018           16.48
# 56  2018           12.29
# 57  2018           15.59
# 58  2018           15.11
# 59  2018           11.66
# 60  2018           19.03
#
#                                                                                              moneda  \
# 51  Working time arrangement coverage: Full-time and part time workers | Currency: AUT - Euro (EUR)
# 52  Working time arrangement coverage: Full-time and part time workers | Currency: AUT - Euro (EUR)
# 53  Working time arrangement coverage: Full-time and part time workers | Currency: AUT - Euro (EUR)
# 54  Working time arrangement coverage: Full-time and part time workers | Currency: AUT - Euro (EUR)
# 55  Working time arrangement coverage: Full-time and part time workers | Currency: AUT - Euro (EUR)
# 56  Working time arrangement coverage: Full-time and part time workers | Currency: AUT - Euro (EUR)
# 57  Working time arrangement coverage: Full-time and part time workers | Currency: AUT - Euro (EUR)
# 58  Working time arrangement coverage: Full-time and part time workers | Currency: AUT - Euro (EUR)
# 59  Working time arrangement coverage: Full-time and part time workers | Currency: AUT - Euro (EUR)
# 60  Working time arrangement coverage: Full-time and part time workers | Currency: AUT - Euro (EUR)
#
#                                                                                                                                                                                                                                                                                                            note_source.label
# 51  Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Reference group coverage: Employees | Establishment size coverage: All establishments with at least 10 employees
# 52  Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Reference group coverage: Employees | Establishment size coverage: All establishments with at least 10 employees
# 53  Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Reference group coverage: Employees | Establishment size coverage: All establishments with at least 10 employees
# 54  Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Reference group coverage: Employees | Establishment size coverage: All establishments with at least 10 employees
# 55  Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Reference group coverage: Employees | Establishment size coverage: All establishments with at least 10 employees
# 56  Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Reference group coverage: Employees | Establishment size coverage: All establishments with at least 10 employees
# 57  Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Reference group coverage: Employees | Establishment size coverage: All establishments with at least 10 employees
# 58  Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Reference group coverage: Employees | Establishment size coverage: All establishments with at least 10 employees
# 59  Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Reference group coverage: Employees | Establishment size coverage: All establishments with at least 10 employees
# 60  Data reference period: October | Economic activity coverage: Excluding agriculture, public administration, and activities of households as employers and of extraterritorial organisations and bodies | Reference group coverage: Employees | Establishment size coverage: All establishments with at least 10 employees

# %% [markdown]
# Se ha elegido los datos de los países que tienen euro para poder hacer el analisis en una misma moneda, por otro lado, debido a que cada país tiene los datos años distintos se hara un analisis macro del año 2014 o 2018, año más actual que tiene la mayoría de países y la regresión de España.

# %%
eu_data.to_csv('datos_procesados3.csv', index=False)
